# %%
# For this notebook to run with updated APIs, we need torch 1.12+ and torchvision 0.13+
try:
    import torch
    import torchvision
    assert int(torch.__version__.split(".")[1]) >= 12, "torch version should be 1.12+"
    assert int(torchvision.__version__.split(".")[1]) >= 13, "torchvision version should be 0.13+"
    print(f"torch version: {torch.__version__}")
    print(f"torchvision version: {torchvision.__version__}")
except:
    print(f"[INFO] torch/torchvision versions not as required, installing nightly versions.")
    # !pip3 install -U torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
    import torch
    import torchvision
    print(f"torch version: {torch.__version__}")
    print(f"torchvision version: {torchvision.__version__}")
# Out:
# [INFO] torch/torchvision versions not as required, installing nightly versions.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\Praveenn\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ---------------------------------------- 60.9/60.9 kB 1.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#      ---------- --------------------------- 153.6/536.2 kB 4.6 MB/s eta 0:00:01
#      ----------------------------- -------- 409.6/536.2 kB 4.2 MB/s eta 0:00:01
#      -------------------------------------- 536.2/536.2 kB 3.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/216.1 MB ? eta -:--:--
# ...

# %%
import shutil
from pathlib import Path

# Create FoodVision mini demo path
foodvision_path = Path("FoodVision_Project/")

# Remove files that might already exist there and create new directory
if foodvision_path.exists():
    shutil.rmtree(foodvision_path)
# If the file doesn't exist, create it anyway
foodvision_path.mkdir(parents=True, exist_ok=True)
    
# Check what's in the folder
# !ls FoodVision/
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.
# WindowsPath('FoodVision_Project')

# %%
import os
# C:\Users\Praveenn\Downloads\FoodVision\examples
foodvision_mini_examples_path = foodvision_path / "examples"
# Get example filepaths in a list of lists
example_list = [["examples/" + example] for example in os.listdir(foodvision_mini_examples_path)]
example_list
# Out:
# [['examples/2582289.jpg'], ['examples/3622237.jpg'], ['examples/592799.jpg']]
